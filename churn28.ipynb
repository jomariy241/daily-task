# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# read  dataset

# %%
df = pd.read_excel('/content/E Commerce Dataset.xlsx', sheet_name='E Comm')
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %% [markdown]
# Understanding the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.describe()
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5366.000000  5630.000000      5379.000000
# mean   52815.500000     0.168384    10.189899     1.654707        15.639896
# std     1625.385339     0.374240     8.557241     0.915389         8.531475
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     2.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    16.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5375.000000               5630.000000        5630.000000
# mean         2.931535                  3.688988           3.066785
# std          0.721926                  1.023999           1.380194
# ...

# %%
df.shape
# Out:
# (5630, 20)

# %%
df.dtypes
# Out:
# CustomerID                       int64
# Churn                            int64
# Tenure                         float64
# PreferredLoginDevice            object
# CityTier                         int64
# WarehouseToHome                float64
# PreferredPaymentMode            object
# Gender                          object
# HourSpendOnApp                 float64
# NumberOfDeviceRegistered         int64
# PreferedOrderCat                object
# SatisfactionScore                int64
# MaritalStatus                   object
# NumberOfAddress                  int64
# Complain                         int64
# OrderAmountHikeFromlastYear    float64
# CouponUsed                     float64
# OrderCount                     float64
# DaySinceLastOrder              float64
# CashbackAmount                 float64
# dtype: object

# %%
df.select_dtypes(include='object').shape[1]
# Out:
# 8

# %%
df.select_dtypes(include='int').shape[1]
# Out:
# 0

# %%
df.select_dtypes(include='float').shape[1]
# Out:
# 18

# %%
df.isnull().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# CustomerID                     0.000000
# Churn                          0.000000
# Tenure                         4.689165
# PreferredLoginDevice           0.000000
# CityTier                       0.000000
# WarehouseToHome                4.458259
# PreferredPaymentMode           0.000000
# Gender                         0.000000
# HourSpendOnApp                 4.529307
# NumberOfDeviceRegistered       0.000000
# PreferedOrderCat               0.000000
# SatisfactionScore              0.000000
# MaritalStatus                  0.000000
# NumberOfAddress                0.000000
# Complain                       0.000000
# OrderAmountHikeFromlastYear    4.706927
# CouponUsed                     4.547069
# OrderCount                     4.582593
# DaySinceLastOrder              5.452931
# CashbackAmount                 0.000000
# dtype: float64

# %%
df['Churn'].value_counts()

# %%
df['PreferredLoginDevice'].value_counts()

# %%
df.loc[df['PreferredLoginDevice'] == 'Phone', 'PreferredLoginDevice' ] = 'Mobile Phone'

# %%
df['PreferredLoginDevice'].value_counts()

# %%
df['PreferredPaymentMode'].value_counts()

# %%
df.loc[df['PreferredPaymentMode'] == 'COD', 'PreferredPaymentMode' ] = 'Cash on Delivery'
df.loc[df['PreferredPaymentMode'] == 'Cash on Delivery', 'PreferredPaymentMode' ] = 'Cash on Delivery'

df.loc[df['PreferredPaymentMode'] == 'Credit Card', 'PreferredPaymentMode' ] = 'Credit Card'
df.loc[df['PreferredPaymentMode'] == 'CC', 'PreferredPaymentMode' ] = 'Credit Card'

# %%
df['Gender'].value_counts()

# %%
df['CityTier'].value_counts()

# %%
df['PreferedOrderCat'].value_counts()

# %%
df['MaritalStatus'].value_counts()

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.drop('CustomerID', axis=1, inplace=True)

df.drop(['CouponUsed'],axis=1,inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Churn                        5630 non-null   int64
#  1   Tenure                       5366 non-null   float64
#  2   PreferredLoginDevice         5630 non-null   object
#  3   CityTier                     5630 non-null   int64
#  4   WarehouseToHome              5379 non-null   float64
#  5   PreferredPaymentMode         5630 non-null   object
#  6   Gender                       5630 non-null   object
#  7   HourSpendOnApp               5375 non-null   float64
#  8   NumberOfDeviceRegistered     5630 non-null   int64
#  9   PreferedOrderCat             5630 non-null   object
#  10  SatisfactionScore            5630 non-null   int64
#  11  MaritalStatus                5630 non-null   object
#  12  NumberOfAddress              5630 non-null   int64
# ...

# %%
columns_with_missing = df.columns[df.isnull().any()]
for column in columns_with_missing:
    plt.figure(figsize=(4,4))
    plt.hist(df[column].dropna(), bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %% [markdown]
# Handling the Missing Values

# %%
for i in df.columns:
    if df[i].dtype in ['float64', 'int64']:
        df[i].fillna(df[i].median(), inplace=True)

for i in df.columns:
    if df[i].dtype == 'object':
        df[i].fillna(df[i].mode()[0], inplace=True)

df.isnull().sum()
# Out:
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %% [markdown]
# Outlier Treatment

# %%
for i in df.columns:
  if((df[i].dtype == 'int64') | (df[i].dtype == 'float64')):
    plt.figure(figsize=(4,4))
    plt.title(i)
    sns.boxplot(df[i])
    plt.show()

# %%
#Customer Churn Rate
churn= (df['Churn'] == 1).sum(), (df['Churn'] == 0).sum()
labels = ['Churn', 'No Churn']
fig = plt.figure(figsize = (4,4))
plt.title('Customer Churn Rate at Company X', size = 14)

plt.pie(churn, labels= labels,autopct='%.0f%%')
plt.show()

# %%
#Distribution of Gender by Churn Status
gender_churn=df.groupby("Churn")["Gender"].value_counts()

gender_churn.plot(kind='bar', stacked=True, color=['blue','pink'], figsize=(10, 6))

plt.title('Distribution of Gender by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# There are currently 3000 male customers who continue to use the company's service, leaving the company. This indicates that the number of female customers remaining with the company is lower compared to male customers.

# %%
#Preferred Login Device
plt.figure(figsize=(5, 6))
sns.countplot(x='PreferredLoginDevice', data=df, color='skyblue', edgecolor='black')
plt.title('Preferred Login Device')
title_font_size=30
plt.xlabel('Device')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 4000 customers are preferred mobile phone

# %%
#PreferredPaymentMode
df1  =df['PreferredPaymentMode'].value_counts().reset_index()
df1.columns = ['mode', 'count']
df1

import plotly.express as px

df1  = df['PreferredPaymentMode'].value_counts().reset_index()
df1.columns = ['mode', 'count']

fig = px.treemap(df1, path=['mode'],values='count',
                 color_discrete_sequence=px.colors.qualitative.Antique,
                 width=600, height=400)
fig.update_layout(title_text='Preferred Payment Mode',
                  title_font_size=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Maximum number of transcation done by debit card and credit card and small portion of payment done by UPI

# %%
#Which commodity are oder most of the time
plt.figure(figsize=(12, 7))
sns.countplot(x='PreferedOrderCat', hue='PreferedOrderCat', data=df,
              palette='cubehelix', legend=False,
              order=df['PreferedOrderCat'].value_counts().index)
plt.xlabel('Preferred commodity')
plt.ylabel('Count')
plt.title('Most ordered commodity')
plt.show()

# %% [markdown]
# Consumer had purchaed mobile and laptop & its accessories maximum number of times

# %%
#distancebetween warehosue to customer house in different city tier
df2 = df.copy()

df2['CityTier'].astype('str')
plt.figure(figsize = (5,7))
sns.stripplot(x = 'CityTier', y = 'WarehouseToHome', data = df2, jitter = False)
plt.title('Distance between warehouse to home')
title_font_size=30
plt.xlabel('City Tier')
plt.ylabel(' Distance between warehouse to home')
plt.show()

# %% [markdown]
# As the distance from warehouse to home is similar in all city tier which means company had build warehouse in lower city tier also.

# %%
sns.countplot(x='MaritalStatus',hue='Churn',data=df,palette='Set2')
plt.title("churn Rates by MaritalStatus")
title_font_size=30
plt.xlabel("Marital Status")
plt.ylabel("Churn Rate")
plt.show()

# %% [markdown]
# single and divorced customers, as they exhibit higher churn rates. For married customers, despite lower churn

# %%
#Which CityTier has the most HourSpendOnApp?
sns.displot(df, x='HourSpendOnApp', col='CityTier')

# %% [markdown]
# city tier 1 has the most spended hours on the app

# %%
import plotly.express as px

comp_ten = df.groupby(["OrderAmountHikeFromlastYear", "Churn"]).size().reset_index(name="Count")
fig_bar = px.bar(comp_ten,
                 x="OrderAmountHikeFromlastYear",
                 y="Count",
                 color="Churn",
                 title="<b>OrderAmountHikeFromlastYear VS Churn</b>",
                 barmode='group',  # Groups bars together for each category
                 color_discrete_sequence=["r", "g"])
fig_bar
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# the percentage of order last year increase and the churn rate decrease so OrderAmountHikeFromlastYear has postive effect on Churn rate

# %%
plt.bar(df['SatisfactionScore'].unique(), df['SatisfactionScore'].value_counts())
plt.title("Satisfactory score of customer on service", fontsize=15)
plt.show()

# %% [markdown]
# most common rating is 2, there is a clear need for service improvement to boost customer satisfaction.

# %% [markdown]
# **Encoding**

# %%
for i in df.columns:
  if(df[i].dtypes == 'object'):
    print(i)
    print(df[i].nunique())
# Out:
# PreferredLoginDevice
# 2
# PreferredPaymentMode
# 5
# Gender
# 2
# PreferedOrderCat
# 6
# MaritalStatus
# 3

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['PreferredLoginDevice'] = le.fit_transform(df['PreferredLoginDevice'])
df['PreferredPaymentMode'] = le.fit_transform(df['PreferredPaymentMode'])
df['PreferedOrderCat'] = le.fit_transform(df['PreferedOrderCat'])
df['MaritalStatus'] = le.fit_transform(df['MaritalStatus'])
df.head()
# Out:
#    Churn  Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0      1     4.0                     1         3              6.0
# 1      1     9.0                     1         1              8.0
# 2      1     9.0                     1         1             30.0
# 3      1     0.0                     1         3             15.0
# 4      1     0.0                     1         1             12.0
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0                     2       0             3.0                         3
# 1                     4       1             3.0                         4
# 2                     2       1             2.0                         4
# 3                     2       1             2.0                         4
# 4                     1       1             3.0                         3
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %% [markdown]
# Data Splitting

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

# %%
from imblearn.combine import SMOTETomek
smt = SMOTETomek(random_state=42)
x_over , y_over = smt.fit_resample(x ,y)

x_over.shape, y_over.shape
# Out:
# ((9364, 17), (9364,))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_over , y_over , test_size = 0.3 , random_state = 42)

# %% [markdown]
# Scaling

# %%
colnames = df.columns
num_columns = df.select_dtypes(include=['float', 'int']).columns
from sklearn.preprocessing import StandardScaler
df[num_columns] = StandardScaler().fit_transform(df[num_columns])

df.head()
# Out:
#       Churn    Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0  2.222345 -0.733989               0.63946  1.469771        -1.146379
# 1  2.222345 -0.135704               0.63946 -0.715286        -0.906721
# 2  2.222345 -0.135704               0.63946 -0.715286         1.729519
# 3  2.222345 -1.212618               0.63946  1.469771        -0.067917
# 4  2.222345 -1.212618               0.63946 -0.715286        -0.427405
#
#    PreferredPaymentMode    Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              0.238584 -1.227468        0.092654                  -0.67290
# 1              2.213919  0.814685        0.092654                   0.30375
# 2              0.238584  0.814685       -1.324850                   0.30375
# 3              0.238584  0.814685       -1.324850                   0.30375
# 4             -0.749084  0.814685        0.092654                  -0.67290
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %% [markdown]
# Hyperparameter Tuning for XGBoost

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report


xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# Set up hyperparameter grid for tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1],
    'colsample_bytree': [0.7, 1],
    'gamma': [0, 0.1, 0.3]
}

# Set up GridSearchCV
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid,
                           scoring='accuracy', cv=5, verbose=1, n_jobs=-1)

# Fit the model
grid_search.fit(x_train, y_train)

# Best parameters and model score
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_}")

# Predict with the best estimator
best_xgb_model = grid_search.best_estimator_
y_pred = best_xgb_model.predict(x_test)

# Evaluate performance
print("Accuracy on test data: ", accuracy_score(y_test, y_pred))
print("Classification report: \n", classification_report(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning:
#
# [06:58:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
# Best parameters found: {'colsample_bytree': 0.7, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 300, 'subsample': 0.8}
# Best accuracy: 0.9829110113484841
# Accuracy on test data:  0.9861209964412812
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1401
#            1       0.98      0.99      0.99      1409
#
#     accuracy                           0.99      2810
#    macro avg       0.99      0.99      0.99      2810
# weighted avg       0.99      0.99      0.99      2810

# %%
#Hyperparameter Tuning for AdaBoost"""

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

base_estimator = DecisionTreeClassifier()

# Initialize the AdaBoost model
ada_model = AdaBoostClassifier(base_estimator=base_estimator)

# Set up hyperparameter grid for tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.5, 1],
    'base_estimator__max_depth': [1, 2, 3, 4],
    'base_estimator__min_samples_split': [2, 5, 10]
}

# Set up GridSearchCV
grid_search_ada = GridSearchCV(estimator=ada_model, param_grid=param_grid,
                               scoring='accuracy', cv=5, verbose=1, n_jobs=-1)

# Fit the model
grid_search_ada.fit(x_train, y_train)

# Best parameters and model score
print(f"Best parameters found: {grid_search_ada.best_params_}")
print(f"Best accuracy: {grid_search_ada.best_score_}")

# Predict with the best estimator
best_ada_model = grid_search_ada.best_estimator_
y_pred_ada = best_ada_model.predict(x_test)

# Evaluate performance
print("Accuracy on test data: ", accuracy_score(y_test, y_pred_ada))
print("Classification report: \n", classification_report(y_test, y_pred_ada))
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning:
#
# `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# Best parameters found: {'base_estimator__max_depth': 4, 'base_estimator__min_samples_split': 2, 'learning_rate': 1, 'n_estimators': 200}
# Best accuracy: 0.9783329548564408
# Accuracy on test data:  0.9765124555160143
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      1401
#            1       0.97      0.98      0.98      1409
#
#     accuracy                           0.98      2810
#    macro avg       0.98      0.98      0.98      2810
# weighted avg       0.98      0.98      0.98      2810

# %% [markdown]
# Advanced AdaBoost Techniques

# %%
# Initialize an AdaBoost model with tuned hyperparameters
ada_advanced = AdaBoostClassifier(
    base_estimator=DecisionTreeClassifier(max_depth=2, min_samples_split=5),
    n_estimators=200,
    learning_rate=0.1
)

# Train the model
ada_advanced.fit(x_train, y_train)

# Predict and evaluate
y_pred_advanced_ada = ada_advanced.predict(x_test)
print("Advanced AdaBoost Model Accuracy: ", accuracy_score(y_test, y_pred_advanced_ada))

# Feature importance from the base estimator
importances = ada_advanced.feature_importances_
feature_names = x.columns

# Plot feature importance
import matplotlib.pyplot as plt
plt.barh(feature_names, importances)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance in AdaBoost")
plt.show()

# Handling class imbalance (if applicable)
from sklearn.utils import resample

# Upsample minority class (example)
x_minority_upsampled, y_minority_upsampled = resample(x_train[y_train == 1], y_train[y_train == 1],
                                                      replace=True, n_samples=len(y_train[y_train == 0]), random_state=42)

# Combine the upsampled minority class with the majority class
x_train_balanced = pd.concat([x_train[y_train == 0], x_minority_upsampled])
y_train_balanced = pd.concat([y_train[y_train == 0], y_minority_upsampled])

# Train on the balanced dataset
ada_advanced_balanced = AdaBoostClassifier(
    base_estimator=DecisionTreeClassifier(max_depth=2, min_samples_split=5),
    n_estimators=200,
    learning_rate=0.1
)

ada_advanced_balanced.fit(x_train_balanced, y_train_balanced)

# Predict and evaluate
y_pred_advanced_ada_balanced = ada_advanced_balanced.predict(x_test)
print("Advanced Balanced AdaBoost Model Accuracy: ", accuracy_score(y_test, y_pred_advanced_ada_balanced))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning:
#
# `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# Advanced AdaBoost Model Accuracy:  0.9138790035587189
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning:
#
# `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# Advanced Balanced AdaBoost Model Accuracy:  0.9128113879003559

# %%
#Hyperparameter Tuning for Random Forest"""

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Initialize the Random Forest model
rf_model = RandomForestClassifier()

# Set up hyperparameter grid for tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Set up GridSearchCV
grid_search_rf = GridSearchCV(estimator=rf_model, param_grid=param_grid,
                              scoring='accuracy', cv=5, verbose=1, n_jobs=-1)

# Fit the model
grid_search_rf.fit(x_train, y_train)

# Best parameters and model score
print(f"Best parameters found: {grid_search_rf.best_params_}")
print(f"Best accuracy: {grid_search_rf.best_score_}")

# Predict with the best estimator
best_rf_model = grid_search_rf.best_estimator_
y_pred_rf = best_rf_model.predict(x_test)

# Evaluate performance
print("Accuracy on test data: ", accuracy_score(y_test, y_pred_rf))
print("Classification report: \n", classification_report(y_test, y_pred_rf))
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best parameters found: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best accuracy: 0.979706884203539
# Accuracy on test data:  0.9846975088967972
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1401
#            1       0.98      0.99      0.98      1409
#
#     accuracy                           0.98      2810
#    macro avg       0.98      0.98      0.98      2810
# weighted avg       0.98      0.98      0.98      2810

# %%
"""Advanced Random Forest Techniques"""

# Initialize a Random Forest model with the tuned hyperparameters
rf_advanced = RandomForestClassifier(
    n_estimators=200,
    max_depth=20,
    min_samples_split=5,
    min_samples_leaf=2,
    bootstrap=True,
    random_state=42
)

# Train the model
rf_advanced.fit(x_train, y_train)

# Predict and evaluate
y_pred_advanced_rf = rf_advanced.predict(x_test)
print("Advanced Random Forest Model Accuracy: ", accuracy_score(y_test, y_pred_advanced_rf))

# Feature importance analysis
importances = rf_advanced.feature_importances_
feature_names = x.columns

# Plot feature importance
import matplotlib.pyplot as plt
plt.barh(feature_names, importances)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance in Random Forest")
plt.show()

# Handling class imbalance (if applicable)
from sklearn.utils import resample

# Upsample minority class (example)
x_minority_upsampled, y_minority_upsampled = resample(x_train[y_train == 1], y_train[y_train == 1],
                                                      replace=True, n_samples=len(y_train[y_train == 0]), random_state=42)

# Combine the upsampled minority class with the majority class
# Use boolean indexing on y_train to select corresponding rows from x_train
x_train_balanced = pd.concat([x_train[y_train == 0], x_minority_upsampled])
y_train_balanced = pd.concat([y_train[y_train == 0], y_minority_upsampled])

# Train on the balanced dataset
rf_advanced_balanced = RandomForestClassifier(
    n_estimators=200,
    max_depth=20,
    min_samples_split=5,
    min_samples_leaf=2,
    bootstrap=True,
    random_state=42
)

rf_advanced_balanced.fit(x_train_balanced, y_train_balanced)

# Predict and evaluate
y_pred_advanced_rf_balanced = rf_advanced_balanced.predict(x_test)
print("Advanced Balanced Random Forest Model Accuracy: ", accuracy_score(y_test, y_pred_advanced_rf_balanced))
# Out:
# Advanced Random Forest Model Accuracy:  0.9768683274021353
# Advanced Balanced Random Forest Model Accuracy:  0.9665480427046264

# %%
#pickle the file
import pickle
with open('model.pkl','wb') as file:
    pickle.dump(xgb_model, file)
    print("model saved")
